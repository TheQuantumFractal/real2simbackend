# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv('../responses.csv')
# Create a new DataFrame with the first three columns removed
new_df = df.drop(columns=[df.columns[0], df.columns[2]])
new_df = new_df.dropna()
new_df
# Out:
#    Tell us your name ;) What do you do for fun? 🤩 (hobbies, activities, etc)  \
# 2          Ali Mottaghi  Hitting the golf course—love the game and the ...
# 3         Anthony Riley                  Run, bike, make jokes, eat, music
# 7        Advait Marathe               Spikeball, Gym, hot chocolate, Chess
# 8           Justin Quan             videography, basketball, weightlifting
# 9           Michael Zhu  volleyball, reading, going to hackathons, talk...
# 10         Akshay Patel  soccer, getting scammed in crypto, surfing, wa...
# 11           Amol Singh                               basketball, hiking,
# 12                J Yim  Concerts / Festivals, Play bass guitar & cello...
#
#                What are your favorite cuisines? 🫄🤰  \
# 2   Big fan of Persian Pizza. It’s a game changer.
# 3                                      Korean Food
# 7                             Asian, Mediterranean
# 8                              chinese, vietnamese
# 9                        mcdonalds and burger king
# 10                          italian, thai, mexican
# 11                 Thai, Indian and Japanese food!
# 12            Japanese & Korean (asian in general)
#
#                           What music do you like? 🎶🎸🥁  \
# 2   Totally into soundtracks. They make every day ...
# 3                          Hyperpop, Yung Lean, Drake
# 7                                            EDM, Pop
# 8                                EDM, Pop, RnB, Indie
# 9                            Classical, Country, Rock
# 10                              EDM, RnB, Indie, Rock
# 11                                      EDM, Pop, RnB
# 12                                                RnB
#
#                   What's your biggest RED flag? ❌😵  \
# 2   Diplomatically left blank to keep things light
# 3                               Often unavailable
# 7                      Takes too long to text back
# 8                                   i'm unemployed
# 9                                  ghosting people
# 10                            suck at texting back
# 11                                       DISLOYAL
# 12                        Lack of ambition in life
#
#            What are your biggest pet peeves / icks? 🤢  \
# 2      Diplomatically left blank to keep things light
# 3                                              stress
# 7        People who aren't passionate about something
# 8   when people buy eggs at brunch when there are ...
# 9                         getting punched in the face
# 10                           chews loudly, annoying,
# 11  someone who has like zero eq and can't read so...
# 12       Body odor/smelling bad and bad skin (lowkey)
#
#         What are your favorite movies / TV shows? 🎥🍿📺  \
# 2   Not into moviesNot huge into movies, but I’m a...
# 3    Sci fi movies: mad max, edge of tomorrow, looper
# 7            Lupin, Money Heist, Friends, Brooklyn 99
# 8             lost, fullmetal alchemist, forrest gump
# 9              game of thrones, altered carbon, borat
# 10                dark, white collar, psych, new girl
# 11                                ATLA, Breaking Bad!
# 12  Pulp Fiction, Chunking Express, Truman Show, I...
#
#    Policy on drugs / alcohol? 💊🥂🥃           Is crypto a scam? 🪙🤑  \
# 2                           Never  my net worth is in $Jeo Boden
# 3                    Occasionally                      of course
# 7                    Occasionally                      of course
# 8                       Sometimes  my net worth is in $Jeo Boden
# 9                    Occasionally  my net worth is in $Jeo Boden
# 10                      Sometimes  my net worth is in $Jeo Boden
# 11                   Occasionally  my net worth is in $Jeo Boden
# 12                          Often                      of course
#
#    Do you like to travel? ✈️🚗🚌  \
# 2          My own bed is comfy
# 3          My own bed is comfy
# 7              I'm rarely home
# 8          My own bed is comfy
# 9          My own bed is comfy
# 10             I'm rarely home
# 11             I'm rarely home
# 12             I'm rarely home
#
#             What are you doing on a Friday night? 👀😈  \
# 2           It's only 5AM? The night is still young!
# 3              Health is wealth (I'm in bed by 10PM)
# 7   Board game nights and kickbacks sound good to me
# 8           It's only 5AM? The night is still young!
# 9   Board game nights and kickbacks sound good to me
# 10             Health is wealth (I'm in bed by 10PM)
# 11          It's only 5AM? The night is still young!
# 12          It's only 5AM? The night is still young!
#
#            What's your best friend's best quality? 🥰🫂  \
# 2             They're real—can’t beat genuine people.
# 3                                          Being open
# 7                                    Extremely caring
# 8                                               funny
# 9                       he also likes ghosting people
# 10                                 supportive, caring
# 11  their loyalty and how much of a clown they are...
# 12  Genuine & super down to earth\nFun person to b...
#
#        What kind of people are you looking to meet? 😉  \
# 2   Looking to meet some smart, driven folks who a...
# 3                                          Cute girls
# 7                       people who make me feel alive
# 8   people who are passionate about what they're d...
# 9                                      single mothers
# 10         fun, driven, passionate about what they do
# 11  im tryna meet some AI baddies that are legenda...
# 12  Rather introverted / down to earth\nOpen to da...
#
#        Are you e/acc or de/acc ⁉️ Do you have any pets? 🐶  \
# 2   I was patient 0 for Neuralink     Yes, I love animals
# 3           electricity scares me   No. but I wish I did!
# 7           electricity scares me   No. but I wish I did!
# 8   I was patient 0 for Neuralink     Yes, I love animals
# 9           electricity scares me       ChatGPT is my pet
# 10  I was patient 0 for Neuralink   No. but I wish I did!
# 11  I was patient 0 for Neuralink     Yes, I love animals
# 12  I was patient 0 for Neuralink     Yes, I love animals
#
#                       What's your ideal first date? 🌹  \
# 2      Good food, great chat—what’s better than that?
# 3                                         Walk / hike
# 7                            Coffee and long ass walk
# 8                               we rob people in soma
# 9                 long walks at civic center at night
# 10            quality time getting to know each other
# 11  to go on a taxing long distnace run and then g...
# 12  Movie Marathon Night / Late Night Drive / Nice...
#
#             What's your favorite emoji? 🤣👻😝🤡👅🤓
# 2   🤡 - Because who doesn’t love a good laugh?
# 3                                            😭
# 7                                            🤡
# 8                                            🛄
# 9                                          👁👅👁
# 10                                           🤣
# 11                                           🐐
# 12                                           🧃

# %%
new_df
question_list = new_df.columns.tolist()
prompt_dict = {}
first_dates = {}
emoji_dict = {}

for row in new_df.itertuples(index=False):
    i = 0
    for question in row:
        if i == 0:
            prompt_dict[question] = "" 
            first_dates[question] = row[15]
            emoji_dict[question] = row[16]
            i += 1
            
        elif question != 'NaN':
            prompt_dict[row[0]] += question_list[i] + row[i] 
            i += 1
            
print(first_dates)
# Out:
# {'Ali Mottaghi': 'Good food, great chat—what’s better than that?', 'Anthony Riley': 'Walk / hike', 'Advait Marathe': 'Coffee and long ass walk', 'Justin Quan': 'we rob people in soma', 'Michael Zhu': 'long walks at civic center at night', 'Akshay Patel': 'quality time getting to know each other', 'Amol Singh': 'to go on a taxing long distnace run and then get bagels', 'J Yim': 'Movie Marathon Night / Late Night Drive / Nice dinner with wine / Lowkey an anime run lol'}

# %%
prompt_dict['Ali Mottaghi']
# Out:
# "What do you do for fun? 🤩 (hobbies, activities, etc)Hitting the golf course—love the game and the quiet it brings.What are your favorite cuisines? \U0001fac4🤰Big fan of Persian Pizza. It’s a game changer.What music do you like? 🎶🎸🥁Totally into soundtracks. They make every day feel epic.What's your biggest RED flag? ❌😵Diplomatically left blank to keep things lightWhat are your biggest pet peeves / icks? 🤢Diplomatically left blank to keep things lightWhat are your favorite movies / TV shows? 🎥🍿📺Not into moviesNot huge into movies, but I’m always down for something that’s a crowd-pleaser.Policy on drugs / alcohol? 💊🥂🥃NeverIs crypto a scam? 🪙🤑my net worth is in $Jeo BodenDo you like to travel? ✈️🚗🚌My own bed is comfyWhat are you doing on a Friday night? 👀😈It's only 5AM? The night is still young!What's your best friend's best quality? 🥰🫂They're real—can’t beat genuine people.What kind of people are you looking to meet? 😉Looking to meet some smart, driven folks who are all about good vibes.Are you e/acc or de/acc ⁉️I was patient 0 for NeuralinkDo you have any pets? 🐶Yes, I love animalsWhat's your ideal first date? 🌹Good food, great chat—what’s better than that?What's your favorite emoji? 🤣👻😝🤡👅🤓🤡 - Because who doesn’t love a good laugh?"

# %%
import json

with open("characters.json", "w") as file:
    json.dump(prompt_dict, file)
with open("first_dates.json", "w") as file:
    json.dump(first_dates, file)
with open("emojis.json", "w") as file:
    json.dump(emoji_dict, file)
